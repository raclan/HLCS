# %% [markdown]
# # Import Packages and Data

# %%
import pandas as pd
import numpy as np
import os

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Raw Data

# %%
cwd = os.getcwd()

date = '11_13_2023'

rd = pd.read_csv(cwd + '/ImportData/RawData/HLCS_RawData_'+ date + '.csv').rename(columns={'Death': 'Deaths'})

# rd['Player'][166] = 'Cobi'
# rd['Champion'][166] = 'Mordekaiser'

rd
# Out:
#           Player    Role  Champion Pick Ban Blue Red  Order  Series #  Game #  \
# 0            NaN     NaN    Rengar      Ban     Blue    1.0       1.0     1.0
# 1            NaN     NaN  Xin Zhao      Ban      Red    1.0       1.0     1.0
# 2            NaN     NaN     Riven      Ban     Blue    2.0       1.0     1.0
# 3            NaN     NaN     Yasuo      Ban      Red    2.0       1.0     1.0
# 4            NaN     NaN      Jhin      Ban     Blue    3.0       1.0     1.0
# ..           ...     ...       ...      ...      ...    ...       ...     ...
# 456          NaN     NaN   Orianna      Ban     Blue    5.0      10.0     3.0
# 457  Jason Canto  Bottom   Caitlyn     Pick      Red    3.0      10.0     3.0
# 458        Miggy     Mid       Vex     Pick     Blue    3.0      10.0     3.0
# 459        Jason  Jungle      Kayn     Pick     Blue    3.0      10.0     3.0
# 460      Wilfred  Jungle    Lillia     Pick      Red    4.0      10.0     3.0
#
#      Kills  Deaths  Assists     CS  Vision Score  Fantasy Score  Damage Dealt
# 0      NaN     NaN      NaN    NaN           NaN           0.00           NaN
# 1      NaN     NaN      NaN    NaN           NaN           0.00           NaN
# 2      NaN     NaN      NaN    NaN           NaN           0.00           NaN
# 3      NaN     NaN      NaN    NaN           NaN           0.00           NaN
# 4      NaN     NaN      NaN    NaN           NaN           0.00           NaN
# ..     ...     ...      ...    ...           ...            ...           ...
# 456    NaN     NaN      NaN    NaN           NaN           0.00           NaN
# 457    7.0     2.0     12.0  174.0          16.0          48.54       18447.0
# 458    1.0     6.0      1.0  139.0           7.0         -10.26       11903.0
# 459    2.0     8.0      1.0  151.0          26.0         -11.19        5858.0
# 460    7.0     2.0     10.0  266.0          15.0          45.41       21783.0
#
# [461 rows x 15 columns]

# %% [markdown]
# ### Clean Data

# %%
rd = rd.dropna(how='all')

# Season Selection
rd = rd[rd['Series #'] >= 4]

rd
# Out:
#           Player    Role    Champion Pick Ban Blue Red  Order  Series #  \
# 105          NaN     NaN    Malphite      Ban     Blue    1.0       4.0
# 106          NaN     NaN   Jarvan IV      Ban      Red    1.0       4.0
# 107          NaN     NaN      Rengar      Ban     Blue    2.0       4.0
# 108          NaN     NaN     Trundle      Ban      Red    2.0       4.0
# 109          NaN     NaN  Blitzcrank      Ban     Blue    3.0       4.0
# ..           ...     ...         ...      ...      ...    ...       ...
# 456          NaN     NaN     Orianna      Ban     Blue    5.0      10.0
# 457  Jason Canto  Bottom     Caitlyn     Pick      Red    3.0      10.0
# 458        Miggy     Mid         Vex     Pick     Blue    3.0      10.0
# 459        Jason  Jungle        Kayn     Pick     Blue    3.0      10.0
# 460      Wilfred  Jungle      Lillia     Pick      Red    4.0      10.0
#
#      Game #  Kills  Deaths  Assists     CS  Vision Score  Fantasy Score  \
# 105     1.0    NaN     NaN      NaN    NaN           NaN           0.00
# 106     1.0    NaN     NaN      NaN    NaN           NaN           0.00
# 107     1.0    NaN     NaN      NaN    NaN           NaN           0.00
# 108     1.0    NaN     NaN      NaN    NaN           NaN           0.00
# 109     1.0    NaN     NaN      NaN    NaN           NaN           0.00
# ..      ...    ...     ...      ...    ...           ...            ...
# 456     3.0    NaN     NaN      NaN    NaN           NaN           0.00
# 457     3.0    7.0     2.0     12.0  174.0          16.0          48.54
# 458     3.0    1.0     6.0      1.0  139.0           7.0         -10.26
# 459     3.0    2.0     8.0      1.0  151.0          26.0         -11.19
# 460     3.0    7.0     2.0     10.0  266.0          15.0          45.41
#
#      Damage Dealt
# 105           NaN
# 106           NaN
# 107           NaN
# 108           NaN
# 109           NaN
# ..            ...
# 456           NaN
# 457       18447.0
# 458       11903.0
# 459        5858.0
# 460       21783.0
#
# [340 rows x 15 columns]

# %% [markdown]
# ### Get Only Player Stats

# %%
raw_ps = rd.loc[rd['Pick Ban'] == 'Pick']
raw_ps
# Out:
#           Player     Role  Champion Pick Ban Blue Red  Order  Series #  \
# 111      Woosung  Support       Lux     Pick     Blue    1.0       4.0
# 112      Anthony   Bottom    Kai'sa     Pick      Red    1.0       4.0
# 113         Cobi  Support     Leona     Pick      Red    1.0       4.0
# 114       Hubert   Bottom      Jhin     Pick     Blue    2.0       4.0
# 115       Declan      Mid  Vladimir     Pick     Blue    2.0       4.0
# ..           ...      ...       ...      ...      ...    ...       ...
# 452          Sam  Support      Rell     Pick      Red    2.0      10.0
# 457  Jason Canto   Bottom   Caitlyn     Pick      Red    3.0      10.0
# 458        Miggy      Mid       Vex     Pick     Blue    3.0      10.0
# 459        Jason   Jungle      Kayn     Pick     Blue    3.0      10.0
# 460      Wilfred   Jungle    Lillia     Pick      Red    4.0      10.0
#
#      Game #  Kills  Deaths  Assists     CS  Vision Score  Fantasy Score  \
# 111     1.0    6.0     2.0     17.0   43.0          39.0          54.38
# 112     1.0    5.0     7.0      3.0  153.0           8.0           6.93
# 113     1.0    0.0    10.0      7.0   24.0          16.0         -14.96
# 114     1.0    9.0     1.0     13.0  158.0          13.0          61.23
# 115     1.0    4.0     2.0     12.0  129.0          15.0          36.04
# ..      ...    ...     ...      ...    ...           ...            ...
# 452     3.0    3.0     3.0     19.0   32.0          51.0          43.87
# 457     3.0    7.0     2.0     12.0  174.0          16.0          48.54
# 458     3.0    1.0     6.0      1.0  139.0           7.0         -10.26
# 459     3.0    2.0     8.0      1.0  151.0          26.0         -11.19
# 460     3.0    7.0     2.0     10.0  266.0          15.0          45.41
#
#      Damage Dealt
# 111       18662.0
# 112       11996.0
# 113        4766.0
# 114       15579.0
# 115       13705.0
# ..            ...
# 452        6273.0
# 457       18447.0
# 458       11903.0
# 459        5858.0
# 460       21783.0
#
# [170 rows x 15 columns]

# %% [markdown]
# ### Convert to Int

# %%
for c in ['Order', 'Series #', 'Game #', 'Kills', 'Deaths', 'Assists', 'CS', 'Vision Score', 'Damage Dealt']:
    raw_ps[c] = raw_ps[c].apply(int)
raw_ps
# Out:
#           Player     Role  Champion Pick Ban Blue Red  Order  Series #  \
# 111      Woosung  Support       Lux     Pick     Blue      1         4
# 112      Anthony   Bottom    Kai'sa     Pick      Red      1         4
# 113         Cobi  Support     Leona     Pick      Red      1         4
# 114       Hubert   Bottom      Jhin     Pick     Blue      2         4
# 115       Declan      Mid  Vladimir     Pick     Blue      2         4
# ..           ...      ...       ...      ...      ...    ...       ...
# 452          Sam  Support      Rell     Pick      Red      2        10
# 457  Jason Canto   Bottom   Caitlyn     Pick      Red      3        10
# 458        Miggy      Mid       Vex     Pick     Blue      3        10
# 459        Jason   Jungle      Kayn     Pick     Blue      3        10
# 460      Wilfred   Jungle    Lillia     Pick      Red      4        10
#
#      Game #  Kills  Deaths  Assists   CS  Vision Score  Fantasy Score  \
# 111       1      6       2       17   43            39          54.38
# 112       1      5       7        3  153             8           6.93
# 113       1      0      10        7   24            16         -14.96
# 114       1      9       1       13  158            13          61.23
# 115       1      4       2       12  129            15          36.04
# ..      ...    ...     ...      ...  ...           ...            ...
# 452       3      3       3       19   32            51          43.87
# 457       3      7       2       12  174            16          48.54
# 458       3      1       6        1  139             7         -10.26
# 459       3      2       8        1  151            26         -11.19
# 460       3      7       2       10  266            15          45.41
#
#      Damage Dealt
# 111         18662
# 112         11996
# 113          4766
# 114         15579
# 115         13705
# ..            ...
# 452          6273
# 457         18447
# 458         11903
# 459          5858
# 460         21783
#
# [170 rows x 15 columns]

# %%
# player_stats2 = player_stats.copy()
# player_stats2['Fantasy Score'] = player_stats2['Kills']*4 - player_stats2['Deaths']*3 + player_stats2['Assists']*2 + player_stats2['CS']*0.01 + player_stats2['Vision Score']*0.05
# player_stats2

# %% [markdown]
# # Game Records

# %%
gr = pd.read_csv(cwd + '/ImportData/GameRecords/HLCS_GameRecords_'+ date + '.csv').dropna(axis=1)
gr
# Out:
#           Date  Series #  Game #                   Blue Side  \
# 0    4/16/2023         1       1           Jason Nguyengards
# 1    4/16/2023         2       1                  Taewonnies
# 2    4/16/2023         3       1                The Founders
# 3    4/30/2023         1       2                  Taewonnies
# 4    4/30/2023         2       2                The Founders
# 5     9/2/2023         4       1  Quintessential Quintuplets
# 6     9/2/2023         4       2                  Taewonnies
# 7     9/2/2023         4       3  Quintessential Quintuplets
# 8    9/23/2023         5       1                   JSA EBOYS
# 9    9/23/2023         5       2                    Triple T
# 10   9/29/2023         6       1             Basil's Dazzles
# 11   9/29/2023         6       2             Liam's Premiums
# 12   9/29/2023         6       3             Basil's Dazzles
# 13  10/13/2023         7       1                 Net Knights
# 14  10/13/2023         7       2            Zazazoso Smokers
# 15  10/21/2023         8       1              Jordan's Jorts
# 16  10/21/2023         8       2             Sammy's Hammies
# 17   11/4/2023         9       1                  The J-Team
# 18   11/4/2023         9       2             The Steph Kuris
# 19  11/12/2023        10       1                Team Streaks
# 20  11/12/2023        10       2                  Team Cupid
# 21  11/12/2023        10       3                Team Streaks
#
#                       Red Side Winning Side Length  Winning Team Gold  \
# 0                   Taewonnies         Blue  44:38              80254
# 1                 The Founders         Blue  36:32              70853
# 2            Jason Nguyengards         Blue  40:58              74186
# 3            Jason Nguyengards         Blue  26:40              52265
# 4                   Taewonnies          Red  35:36              66563
# 5                   Taewonnies         Blue  25:07              48734
# 6   Quintessential Quintuplets         Blue  26:07              35004
# 7                   Taewonnies         Blue  34:54              68937
# 8                     Triple T          Red  36:40              68560
# 9                    JSA EBOYS          Red  64:35             128319
# 10             Liam's Premiums         Blue  31:00              63623
# 11             Basil's Dazzles         Blue  28:55              63330
# 12             Liam's Premiums          Red  36:55              74209
# 13            Zazazoso Smokers         Blue  37:45              74039
# 14                 Net Knights          Red  32:21              62185
# 15             Sammy's Hammies          Red  31:15              61878
# 16              Jordan's Jorts         Blue  42:41              82206
# 17             The Steph Kuris         Blue  29:08              61369
# 18                  The J-Team          Red  32:17              63345
# 19                  Team Cupid          Red  39:10              74140
# 20                Team Streaks          Red  42:34              79732
# 21                  Team Cupid          Red  27:28              59447
#
#     Losing Team Gold  Winning Team Kills  Losing Team Kills  Forfeit
# 0              74816                  40                 23    False
# 1              57956                  32                 18    False
# 2              59663                  31                 13    False
# 3              41261                  29                 11    False
# 4              52974                  27                 12    False
# 5              37377                  31                  9    False
# 6              25886                  18                  8     True
# 7              60256                  32                 22    False
# 8              57739                  29                 20    False
# 9             119728                  50                 41    False
# 10             49905                  37                 15    False
# 11             49871                  38                 23    False
# 12             70158                  40                 38    False
# 13             70973                  46                 43    False
# 14             55959                  23                 23    False
# 15             56471                  21                 27    False
# 16             74799                  35                 32    False
# 17             47626                  38                 19    False
# 18             50777                  27                 19    False
# 19             65845                  29                 20    False
# 20             76864                  41                 29    False
# 21             41945                  33                 11    False

# %% [markdown]
# ### Round Up Game Length

# %%
gr['Length'] = pd.Series(l.split(':')[0] for l in gr['Length']).apply(int) + 1
gr
# Out:
#           Date  Series #  Game #                   Blue Side  \
# 0    4/16/2023         1       1           Jason Nguyengards
# 1    4/16/2023         2       1                  Taewonnies
# 2    4/16/2023         3       1                The Founders
# 3    4/30/2023         1       2                  Taewonnies
# 4    4/30/2023         2       2                The Founders
# 5     9/2/2023         4       1  Quintessential Quintuplets
# 6     9/2/2023         4       2                  Taewonnies
# 7     9/2/2023         4       3  Quintessential Quintuplets
# 8    9/23/2023         5       1                   JSA EBOYS
# 9    9/23/2023         5       2                    Triple T
# 10   9/29/2023         6       1             Basil's Dazzles
# 11   9/29/2023         6       2             Liam's Premiums
# 12   9/29/2023         6       3             Basil's Dazzles
# 13  10/13/2023         7       1                 Net Knights
# 14  10/13/2023         7       2            Zazazoso Smokers
# 15  10/21/2023         8       1              Jordan's Jorts
# 16  10/21/2023         8       2             Sammy's Hammies
# 17   11/4/2023         9       1                  The J-Team
# 18   11/4/2023         9       2             The Steph Kuris
# 19  11/12/2023        10       1                Team Streaks
# 20  11/12/2023        10       2                  Team Cupid
# 21  11/12/2023        10       3                Team Streaks
#
#                       Red Side Winning Side  Length  Winning Team Gold  \
# 0                   Taewonnies         Blue      45              80254
# 1                 The Founders         Blue      37              70853
# 2            Jason Nguyengards         Blue      41              74186
# 3            Jason Nguyengards         Blue      27              52265
# 4                   Taewonnies          Red      36              66563
# 5                   Taewonnies         Blue      26              48734
# 6   Quintessential Quintuplets         Blue      27              35004
# 7                   Taewonnies         Blue      35              68937
# 8                     Triple T          Red      37              68560
# 9                    JSA EBOYS          Red      65             128319
# 10             Liam's Premiums         Blue      32              63623
# 11             Basil's Dazzles         Blue      29              63330
# 12             Liam's Premiums          Red      37              74209
# 13            Zazazoso Smokers         Blue      38              74039
# 14                 Net Knights          Red      33              62185
# 15             Sammy's Hammies          Red      32              61878
# 16              Jordan's Jorts         Blue      43              82206
# 17             The Steph Kuris         Blue      30              61369
# 18                  The J-Team          Red      33              63345
# 19                  Team Cupid          Red      40              74140
# 20                Team Streaks          Red      43              79732
# 21                  Team Cupid          Red      28              59447
#
#     Losing Team Gold  Winning Team Kills  Losing Team Kills  Forfeit
# 0              74816                  40                 23    False
# 1              57956                  32                 18    False
# 2              59663                  31                 13    False
# 3              41261                  29                 11    False
# 4              52974                  27                 12    False
# 5              37377                  31                  9    False
# 6              25886                  18                  8     True
# 7              60256                  32                 22    False
# 8              57739                  29                 20    False
# 9             119728                  50                 41    False
# 10             49905                  37                 15    False
# 11             49871                  38                 23    False
# 12             70158                  40                 38    False
# 13             70973                  46                 43    False
# 14             55959                  23                 23    False
# 15             56471                  21                 27    False
# 16             74799                  35                 32    False
# 17             47626                  38                 19    False
# 18             50777                  27                 19    False
# 19             65845                  29                 20    False
# 20             76864                  41                 29    False
# 21             41945                  33                 11    False

# %%
# Wins
# Losses 
# Win Percentage 
# Kills *
# Deaths *
# Assists *
# KDA 
# CS *
# Vision Score *
# Fantasy Score *
# Average Score 
# Total Kills of Team 
# Kill Participation 
# Minutes Played 
# CS/Min 
# Average CS/Min 
# Average Kills
# Average Deaths 
# Average Assists

# %%
# ryan = raw_ps.loc[raw_ps['Player'] == 'Ryan'].join(gr.set_index(['Series #', 'Game #']), on=['Series #', 'Game #'])
# ryan

# %%
# ryan_wins = np.count_nonzero((ryan['Blue Red'] == ryan['Winning Side']))
# print("wins:", ryan_wins)

# ryan_losses = np.count_nonzero((ryan['Blue Red'] == ryan['Winning Side']) == 0)
# print("Losses:", ryan_losses)

# print("Win Percentage:", ryan_wins / (ryan_wins + ryan_losses) * 100)

# ryan_kills = sum(ryan['Kills'])
# print('Kills:', ryan_kills)

# ryan_deaths = sum(ryan['Deaths'])
# print('Deaths:', ryan_deaths)

# ryan_assists = sum(ryan['Assists'])
# print('Assists:', ryan_assists)

# print("KDA:", (ryan_kills + ryan_assists) / ryan_deaths)

# ryan_cs = sum(ryan['CS'])
# print('CS:', ryan_cs)

# ryan_vision_score = sum(ryan['Vision Score'])
# print('Vision Score:', ryan_vision_score)

# ryan_fantasy_score = sum(ryan['Fantasy Score'])
# print('Fantasy Score:', ryan_fantasy_score)

# print('Average Fantasy Score:', ryan_fantasy_score / (ryan_wins + ryan_losses))

# ryan_total_kills = sum(ryan.loc[ryan['Blue Red'] == ryan['Winning Side']]['Winning Team Kills']) + sum(ryan.loc[(ryan['Blue Red'] == ryan['Winning Side']) == 0]['Losing Team Kills'])
# print('Total Kills of Team:', ryan_total_kills)

# print('Kill Participation:', (ryan_kills + ryan_assists) / ryan_total_kills) 

# ryan_minutes = sum(ryan['Length'])
# print('Minutes Played:', ryan_minutes) 

# ryan_csmin = sum(ryan['CS']) / ryan_minutes
# print('CS/Min:', ryan_csmin) 

# print('Average CS/Min:', ryan_csmin / (ryan_wins + ryan_losses)) 

# print('Average Kills:', ryan_kills / (ryan_wins + ryan_losses)) 

# print('Average Deaths:', ryan_deaths / (ryan_wins + ryan_losses)) 

# print('Average Assists', ryan_assists / (ryan_wins + ryan_losses))

# %% [markdown]
# # Player Stats

# %%
# return row of stats for given player

def get_stats(player, champion = False):
    
    if champion:
        ps_gr = raw_ps.loc[raw_ps['Champion'] == player].join(gr.set_index(['Series #', 'Game #']), on=['Series #', 'Game #'])
    else:
        ps_gr = raw_ps.loc[raw_ps['Player'] == player].join(gr.set_index(['Series #', 'Game #']), on=['Series #', 'Game #'])

    wins = np.count_nonzero((ps_gr['Blue Red'] == ps_gr['Winning Side']))

    losses = np.count_nonzero((ps_gr['Blue Red'] == ps_gr['Winning Side']) == 0)

    win_p = round(wins / (wins + losses), 3)

    kills = sum(ps_gr['Kills'])

    deaths = sum(ps_gr['Deaths'])

    assists = sum(ps_gr['Assists'])

    if deaths == 0:
        kda = kills + assists
    else:
        kda = round((kills + assists) / deaths, 3)

    cs = sum(ps_gr['CS'])

    vision_score = sum(ps_gr['Vision Score'])

    avg_vision_score = round(vision_score / (wins + losses), 3)

    fantasy_score = sum(ps_gr['Fantasy Score'])

    avg_fantasy_score = round(fantasy_score / (wins + losses), 3)

    total_kills = sum(ps_gr.loc[ps_gr['Blue Red'] == ps_gr['Winning Side']]['Winning Team Kills']) + sum(ps_gr.loc[(ps_gr['Blue Red'] == ps_gr['Winning Side']) == 0]['Losing Team Kills'])

    kp = round((kills + assists) / total_kills, 3)

    minutes = sum(ps_gr['Length'])

    csmin = round(sum(ps_gr['CS']) / minutes, 3)

    avg_kills = round(kills / (wins + losses), 3)

    avg_deaths = round(deaths / (wins + losses), 3)

    avg_assists = round(assists / (wins + losses), 3)

    kpm = round(kills / minutes, 3)

    dpm = round(deaths / minutes, 3)

    apm = round(assists / minutes, 3)

    damage_dealt = sum(ps_gr['Damage Dealt'])

    ddpm = round(damage_dealt / minutes, 3)

    return [player, wins, losses, win_p, kills, deaths, assists, kda, cs, vision_score, avg_vision_score, fantasy_score, avg_fantasy_score, total_kills, kp, minutes, csmin, avg_kills, avg_deaths, avg_assists, kpm, dpm, apm, damage_dealt, ddpm]

# %%
final_ps = pd.DataFrame(columns=['Player', 'Wins', 'Losses', 'Win Percentage', 'Kills', 'Deaths', 'Assists', 'KDA', 'CS', 'Vision Score', 'Average Vision Score', 'Fantasy Score', 'Average Score' , 'Total Kills of Team' , 'Kill Participation' , 'Minutes Played' , 'CS/Min' , 'Average Kills', 'Average Deaths', 'Average Assists', 'Kills/Minute', 'Deaths/Minute', 'Assists/Minute', 'Damage Dealt', 'DPM'])

# %%
for p in raw_ps['Player'].unique():
    final_ps.loc[len(final_ps)] = get_stats(p)

# %%
final_ps = final_ps.sort_values(by=['Average Score', 'Win Percentage', 'Wins'], ascending=False).reset_index(drop=True)
final_ps
# Out:
#          Player  Wins  Losses  Win Percentage  Kills  Deaths  Assists    KDA  \
# 0          Liam     3       6           0.333     83      52       96  3.442
# 1         Jason     4       2           0.667     40      28       62  3.643
# 2         Bobby     4       0           1.000     46      33       22  2.061
# 3       Wilfred     2       1           0.667     24      14       20  3.143
# 4          Quio     7       6           0.538     95      70      120  3.071
# 5        Jordan     6       4           0.600     82      52       64  2.808
# 6   Jason Canto     4       3           0.571     39      29       72  3.828
# 7     Stephanie     0       2           0.000     15      10       12  2.700
# 8        Hubert     5       9           0.357     80      84      149  2.726
# 9       Anthony    11       6           0.647    124     102      123  2.422
# 10      Woosung     5      10           0.333     65      92      181  2.674
# 11       Declan     3       5           0.375     39      33       66  3.182
# 12         Cobi     7       7           0.500     76      78      128  2.615
# 13        Basil     5       5           0.500     62      58       67  2.224
# 14          Sam     9       8           0.529     41     108      215  2.370
# 15        Chris     2       3           0.400     10      22       36  2.091
# 16        Miggy     4       6           0.400     32      71       95  1.789
# 17       Hunter     2       2           0.500     10      16       15  1.562
# 18      Bwosley     2       0           1.000      4      17       11  0.882
#
#       CS  Vision Score  ...  Minutes Played  CS/Min  Average Kills  \
# 0   2408           199  ...             346   6.960          9.222
# 1   1566           270  ...             239   6.552          6.667
# 2    971            81  ...             146   6.651         11.500
# 3    842            63  ...             111   7.586          8.000
# 4   2924           351  ...             474   6.169          7.308
# 5   2279           321  ...             324   7.034          8.200
# 6   1239           190  ...             249   4.976          5.571
# 7    415            28  ...              63   6.587          7.500
# 8   2064           481  ...             497   4.153          5.714
# 9   3765           406  ...             608   6.192          7.294
# 10  1463           766  ...             533   2.745          4.333
# 11  1344           171  ...             249   5.398          4.875
# 12  2213           325  ...             510   4.339          5.429
# 13  2159           248  ...             355   6.082          6.200
# 14  1482           978  ...             608   2.438          2.412
# 15   818           165  ...             190   4.305          2.000
# 16  1322           123  ...             382   3.461          3.200
# 17   543            73  ...             125   4.344          2.500
# 18   266            54  ...              71   3.746          2.000
#
#     Average Deaths  Average Assists  Kills/Minute  Deaths/Minute  \
# 0            5.778           10.667         0.240          0.150
# 1            4.667           10.333         0.167          0.117
# 2            8.250            5.500         0.315          0.226
# 3            4.667            6.667         0.216          0.126
# 4            5.385            9.231         0.200          0.148
# 5            5.200            6.400         0.253          0.160
# 6            4.143           10.286         0.157          0.116
# 7            5.000            6.000         0.238          0.159
# 8            6.000           10.643         0.161          0.169
# 9            6.000            7.235         0.204          0.168
# 10           6.133           12.067         0.122          0.173
# 11           4.125            8.250         0.157          0.133
# 12           5.571            9.143         0.149          0.153
# 13           5.800            6.700         0.175          0.163
# 14           6.353           12.647         0.067          0.178
# 15           4.400            7.200         0.053          0.116
# 16           7.100            9.500         0.084          0.186
# 17           4.000            3.750         0.080          0.128
# 18           8.500            5.500         0.056          0.239
#
#     Assists/Minute  Damage Dealt      DPM
# 0            0.277        324415  937.616
# 1            0.259        178846  748.310
# 2            0.151        143990  986.233
# 3            0.180         70995  639.595
# 4            0.253        394295  831.846
# 5            0.198        214540  662.160
# 6            0.289        139681  560.968
# 7            0.190         45061  715.254
# 8            0.300        251920  506.881
# 9            0.202        399327  656.788
# 10           0.340        213035  399.690
# 11           0.265        152199  611.241
# 12           0.251        298593  585.476
# 13           0.189        218881  616.566
# 14           0.354        229243  377.044
# 15           0.189         58265  306.658
# 16           0.249        115767  303.055
# 17           0.120         50188  401.504
# 18           0.155         26795  377.394
#
# [19 rows x 25 columns]

# %%
# final_ps.to_csv(cwd + '/ExportData/PlayerStats/HLCS_player_statistics_'+ date + '.csv', index=False)

final_ps.to_csv(cwd + '/S2_HLCS_player_statistics.csv', index=False)

# %% [markdown]
# # Role Analysis

# %% [markdown]
# ## Flexibility Scores

# %%
# ryan_roles = raw_ps[raw_ps['Player'] == 'Ryan']['Role'].value_counts()

# ryan_top = 0
# ryan_jungle = 0
# ryan_mid = 0
# ryan_bottom = 0
# ryan_support = 0

# for i in range(len(ryan_roles)):
#     match ryan_roles.index[i]:
#         case 'Top':
#             ryan_top = ryan_roles[i]
#         case 'Jungle':
#             ryan_jungle = ryan_roles[i]
#         case 'Mid':
#             ryan_mid = ryan_roles[i]
#         case 'Bottom':
#             ryan_bottom = ryan_roles[i]
#         case 'Support':
#             ryan_support = ryan_roles[i]

# ryan_flex_score = 1 - np.std([ryan_top, ryan_jungle, ryan_mid, ryan_bottom, ryan_support] / (ryan_top + ryan_jungle + ryan_mid + ryan_bottom + ryan_support), ddof=1)
# ryan_flex_score

# %%
def get_roles(player):
    roles = raw_ps[raw_ps['Player'] == player]['Role'].value_counts()

    top = 0
    jungle = 0
    mid = 0
    bottom = 0
    support = 0

    for i in range(len(roles)):
        match roles.index[i]:
            case 'Top':
                top = roles[i]
            case 'Jungle':
                jungle = roles[i]
            case 'Mid':
                mid = roles[i]
            case 'Bottom':
                bottom = roles[i]
            case 'Support':
                support = roles[i]

    flex_score = 1 - np.std([top, jungle, mid, bottom, support] / (top + jungle + mid + bottom + support), ddof=4)

    return [player, top, jungle, mid, bottom, support, flex_score]

# %%
flex_scores = pd.DataFrame(columns=['Player', 'Top', 'Jungle', 'Mid', 'Bottom', 'Support', 'Flex Score'])

for p in raw_ps['Player'].unique():
    flex_scores.loc[len(flex_scores)] = get_roles(p)

# %%
flex_scores = flex_scores.sort_values(by='Flex Score', ascending=False).reset_index(drop=True)
flex_scores
# Out:
#          Player  Top  Jungle  Mid  Bottom  Support  Flex Score
# 0          Quio    3       5    4       5        0    0.756042
# 1         Chris    3       2    1       0        2    0.714956
# 2   Jason Canto    1       0    2       3        1    0.674236
# 3          Ryan    0       1    1       0        1    0.634852
# 4         Jason    1       5    1       1        1    0.602477
# 5       Bwosley    2       0    2       0        1    0.600000
# 6        Jordan    3       5    0       2        0    0.575736
# 7       Woosung    3       6    0       0        9    0.565387
# 8           Sam    0       6    4       0       11    0.561491
# 9        Hubert    1       2    0      10        4    0.532362
# 10         Cobi    9       0    2       0        6    0.532362
# 11         Liam    0       5    1       3        0    0.518234
# 12    Stephanie    0       0    1       1        0    0.452277
# 13       Eunice    0       0    2       0        1    0.403715
# 14        Basil   10       3    1       0        0    0.398980
# 15       Declan    1       0    8       2        0    0.391520
# 16        Miggy    0       0    9       0        4    0.388474
# 17       Hunter    3       0    0       0        1    0.348080
# 18        Bobby    1       0    3       0        0    0.348080
# 19      Anthony    2       0    2      17        0    0.311909
# 20       Meagan    0       0    0       0        1    0.105573
# 21         Sean    0       2    0       0        0    0.105573
# 22      Wilfred    0       3    0       0        0    0.105573

# %%
flex_scores.to_csv(cwd + '/ExportData/FlexScores/HLCS_flex_scores_'+ date + '.csv', index=False)

# %% [markdown]
# ## All-Pro

# %%
def get_role_scores(player):

    scores = [player]

    for r in ['Top', 'Jungle', 'Mid', 'Bottom', 'Support']:
        scores.append(np.sum(raw_ps[raw_ps['Player'] == player][raw_ps['Role'] == r]['Fantasy Score']))

    return scores

# %%
role_scores = pd.DataFrame(columns=['Player', 'Top', 'Jungle', 'Mid', 'Bottom', 'Support'])

for p in raw_ps['Player'].unique():
    role_scores.loc[len(role_scores)] = get_role_scores(p)

# %%
def get_player_champion_stats(player, champion):
    games = len(raw_ps[raw_ps['Player'] == player][raw_ps['Champion'] == champion])
    average_fantasy_score = round(np.mean(raw_ps[raw_ps['Player'] == player][raw_ps['Champion'] == champion]['Fantasy Score']), 3)
    variance = round(np.std(raw_ps[raw_ps['Player'] == player][raw_ps['Champion'] == champion]['Fantasy Score']), 3)

    return [player, champion, games, average_fantasy_score, variance]

# %%
player_champion_stats = pd.DataFrame(columns=['Player', 'Champion', 'Games Played', 'Average Fantasy Score', 'Standard Deviation'])

for p in np.unique(raw_ps['Player']):
    for c in np.unique(raw_ps[raw_ps['Player'] == p]['Champion']):
        player_champion_stats.loc[len(player_champion_stats)] = get_player_champion_stats(p, c)

# %%
player_champion_stats[player_champion_stats['Games Played'] > 1].sort_values(by='Average Fantasy Score', ascending=False)
# Out:
#       Player     Champion  Games Played  Average Fantasy Score  \
# 16     Basil      Kindred             2                 54.120
# 3    Anthony         Jinx             4                 49.405
# 110     Quio       Ezreal             2                 48.525
# 5    Anthony      Kalista             2                 44.450
# 56    Hubert         Jhin             3                 44.130
# 143  Woosung          Lux             2                 42.385
# 49    Declan       Syndra             3                 41.137
# 4    Anthony       Kai'sa             5                 37.430
# 113     Quio          Jax             2                 37.385
# 119     Quio        Xayah             2                 36.710
# 132      Sam        Swain             3                 34.087
# 65    Hubert        Xayah             2                 33.115
# 92    Jordan   Tryndamere             2                 31.810
# 41      Cobi  Mordekaiser             2                 29.595
# 90    Jordan       Rengar             3                 28.157
# 36      Cobi   Blitzcrank             5                 27.732
# 123      Sam        Amumu             5                 27.468
# 48    Declan      Orianna             3                 27.030
# 11     Basil         Gnar             4                 26.442
# 55    Hubert       Ezreal             2                 25.465
# 140  Woosung      Alistar             5                 25.336
# 121     Ryan      Morgana             2                 24.575
# 2    Anthony         Jhin             4                 23.908
# 37      Cobi        Garen             5                 22.310
# 111     Quio       Graves             2                 21.990
# 148  Woosung           Vi             3                 21.053
# 94      Liam     Bel'veth             2                 19.130
# 17     Basil        Riven             2                 18.290
# 64    Hubert           Vi             2                 14.795
# 130      Sam         Rell             2                 13.980
# 149  Woosung     Xin Zhao             2                 10.680
# 106    Miggy    Seraphine             4                 10.170
# 107    Miggy          Vex             4                  9.822
# 128      Sam     Nautilus             5                  9.762
# 102    Miggy        Galio             2                  9.320
# 38      Cobi        Leona             2                  1.790
#
#      Standard Deviation
# 16               24.500
# 3                13.804
# 110              39.875
# 5                49.860
# 56               26.842
# 143              11.995
# 49               16.884
# 4                20.863
# 113               2.695
# 119              28.780
# 132              21.406
# 65                9.585
# 92               15.970
# 41                7.135
# 90                6.644
# 36                3.440
# 123              12.770
# 48               25.969
# 11               10.368
# 55               19.155
# 140              20.654
# 121              16.005
# 2                12.587
# 37               10.767
# 111               4.720
# 148              23.989
# 94               19.350
# 17               18.750
# 64               19.215
# 130              29.890
# 149               5.880
# 106              23.642
# 107              17.803
# 128              12.497
# 102              20.730
# 38               16.750

# %%
champion_pool = pd.DataFrame(columns=['Player', 'Champions Played'])

played_champions = []
for p in np.unique(raw_ps['Player']):
    played_champions.append(len(np.unique(raw_ps[raw_ps['Player'] == p]['Champion'])))

champion_pool['Player'] = np.unique(raw_ps['Player'])
champion_pool['Champions Played'] = played_champions

champion_pool.sort_values(by='Champions Played', ascending=False)
# Out:
#          Player  Champions Played
# 16         Quio                13
# 8        Hubert                12
# 0       Anthony                10
# 18          Sam                10
# 22      Woosung                10
# 10        Jason                 9
# 1         Basil                 9
# 5          Cobi                 8
# 4         Chris                 8
# 13         Liam                 8
# 12       Jordan                 7
# 6        Declan                 7
# 11  Jason Canto                 7
# 15        Miggy                 6
# 3       Bwosley                 5
# 9        Hunter                 4
# 2         Bobby                 4
# 7        Eunice                 3
# 21      Wilfred                 3
# 17         Ryan                 2
# 19         Sean                 2
# 20    Stephanie                 2
# 14       Meagan                 1

# %% [markdown]
# # Champion Analysis

# %%
champs_ps = pd.DataFrame(columns=['Champion', 'Wins', 'Losses', 'Win Percentage', 'Kills', 'Deaths', 'Assists', 'KDA', 'CS', 'Vision Score', 'Average Vision Score', 'Fantasy Score', 'Average Score' , 'Total Kills of Team' , 'Kill Participation' , 'Minutes Played' , 'CS/Min' , 'Average Kills', 'Average Deaths', 'Average Assists', 'Kills/Minute', 'Deaths/Minute', 'Assists/Minute', 'Damage Dealt', 'DPM'])

for c in raw_ps['Champion'].unique():
    champs_ps.loc[len(champs_ps)] = get_stats(c, True)

# %%
champs_ps = champs_ps.sort_values(by=['Average Score', 'Win Percentage', 'Wins'], ascending=False).reset_index(drop=True)

# %%
champs_ps.filter(['Champion', 'Wins', 'Losses', 'Kills', 'Deaths', 'Assists', 'Fantasy', 'Average Score'])
# Out:
#      Champion  Wins  Losses  Kills  Deaths  Assists  Average Score
# 0   Gangplank     1       0     20       9        9         78.040
# 1       Shaco     1       0     15       4       10         71.750
# 2      Draven     1       0     14       3        8         66.820
# 3       Varus     1       1     25       9       18         58.085
# 4    Nocturne     1       0      5       4       22         57.100
# ..        ...   ...     ...    ...     ...      ...            ...
# 89     Gragas     0       1      0       3        1         -3.810
# 90     Anivia     0       1      0       3        0         -7.290
# 91      Milio     0       1      0       6        3         -9.410
# 92       Kayn     0       1      2       8        1        -11.190
# 93       Udyr     0       1      2       9        1        -14.180
#
# [94 rows x 7 columns]

# %%
def champ_stats(champion, games):
    rd_gr = rd.loc[rd['Champion'] == champion].join(gr.set_index(['Series #', 'Game #']), on=['Series #', 'Game #'])

    picks = np.count_nonzero(rd_gr['Pick Ban'] == 'Pick')

    bans = np.count_nonzero(rd_gr['Pick Ban'] == 'Ban')

    picked = rd_gr.loc[rd_gr['Pick Ban'] == 'Pick']
    wins = np.count_nonzero((picked['Blue Red'] == picked['Winning Side']))

    presence = round((picks + bans) / games, 3)

    pickrate = round(picks / games, 3)

    banrate = round(bans / games, 3)

    if len(picked) == 0:
        winrate = 0
    else:
        winrate = round(wins / len(picked), 3)

    return [champion, picks, bans, wins, presence, pickrate, banrate, winrate]

# %%
champ_pb = pd.DataFrame(columns=['Champion', 'Picks', 'Bans', 'Wins', 'Presence', 'Pickrate', 'Banrate', 'Winrate'])
                        
games = len(rd.filter(['Series #', 'Game #']).drop_duplicates().dropna())

for c in rd['Champion'].unique():
    champ_pb.loc[len(champ_pb)] = champ_stats(c, games)

# %%
champ_pb = champ_pb.sort_values('Champion').dropna().reset_index(drop=True)
champ_pb
# Out:
#      Champion  Picks  Bans  Wins  Presence  Pickrate  Banrate  Winrate
# 0      Aatrox    1.0   0.0   0.0     0.045     0.045    0.000    0.000
# 1        Ahri    3.0   2.0   0.0     0.227     0.136    0.091    0.000
# 2       Akali    0.0   4.0   0.0     0.182     0.000    0.182    0.000
# 3     Alistar    6.0   1.0   3.0     0.318     0.273    0.045    0.500
# 4       Amumu    6.0   7.0   4.0     0.591     0.273    0.318    0.667
# ..        ...    ...   ...   ...       ...       ...      ...      ...
# 96   Xin Zhao    2.0   6.0   0.0     0.364     0.091    0.273    0.000
# 97      Yasuo    1.0   4.0   1.0     0.227     0.045    0.182    1.000
# 98        Zac    1.0   0.0   0.0     0.045     0.045    0.000    0.000
# 99        Zed    1.0   1.0   0.0     0.091     0.045    0.045    0.000
# 100     Ziggs    2.0   0.0   0.0     0.091     0.091    0.000    0.000
#
# [101 rows x 8 columns]

# %%
champ_pb.to_csv(cwd + '/ExportData/PickBan/HLCS_pickban_'+ date + '.csv', index=False)

# %% [markdown]
# ### Extra Analysis

# %%
raw_ps.sort_values('Fantasy Score', ascending=False)[0:10].drop(['Pick Ban', 'Blue Red', 'Order'], axis=1)
# Out:
#       Player    Role   Champion  Series #  Game #  Kills  Deaths  Assists  \
# 241     Liam  Bottom      Varus         6       2     20       2        9
# 427  Anthony  Bottom    Kalista        10       2     19       4       13
# 196     Quio  Bottom     Ezreal         5       2     14       5       21
# 18     Jason  Jungle  Jarvan IV         1       1     13       1       16
# 290    Bobby     Mid      Quinn         7       1     23      10        8
# 38     Basil  Jungle    Kindred         2       1     13       2       14
# 208    Jason     Top  Gangplank         5       2     20       9        9
# 354    Basil  Jungle      Shaco         8       2     15       4       10
# 195     Liam  Bottom     Kai'sa         5       2     13       6       14
# 153   Jordan  Bottom     Draven         4       3     14       3        8
#
#       CS  Vision Score  Fantasy Score  Damage Dealt
# 241  262            19          95.57         44100
# 427  271            32          94.31         38152
# 196  215            65          88.40         92134
# 18   319            63          87.34         28766
# 290  172            28          81.12         43997
# 38   277            37          78.62         36150
# 208  534            34          78.04         96769
# 354  240            27          71.75         44786
# 195  454            37          68.39        100643
# 153  247            27          66.82         33130

# %%
raw_ps.sort_values('Fantasy Score')[0:10].drop(['Pick Ban', 'Blue Red', 'Order'], axis=1)
# Out:
#      Player     Role   Champion  Series #  Game #  Kills  Deaths  Assists  \
# 71    Miggy  Support  Seraphine         1       2      0       8        3
# 364     Sam   Jungle       Rell         9       1      0      10        6
# 113    Cobi  Support      Leona         4       1      0      10        7
# 430     Sam  Support   Nautilus        10       2      0      12        8
# 94     Ryan   Jungle       Udyr         2       2      2       9        1
# 217   Miggy      Mid      Galio         6       1      0       7        4
# 459   Jason   Jungle       Kayn        10       3      2       8        1
# 19     Cobi      Mid   Malzahar         1       1      1      11        7
# 458   Miggy      Mid        Vex        10       3      1       6        1
# 221  Hubert  Support      Milio         6       1      0       6        3
#
#       CS  Vision Score  Fantasy Score  Damage Dealt
# 71     7            17         -17.08          2689
# 364   94            23         -15.91          5033
# 113   24            16         -14.96          4766
# 430   33            99         -14.72          7406
# 94   167            23         -14.18          6718
# 217  124             7         -11.41          6729
# 459  151            26         -11.19          5858
# 19   277            21         -11.18         13549
# 458  139             7         -10.26         11903
# 221    9            50          -9.41          3590

# %%
final_ps.sort_values(by=['Fantasy Score'], ascending=False).filter(['Player', 'Fantasy Score'])[0:5]
# Out:
#      Player  Fantasy Score
# 7   Anthony         688.21
# 1      Quio         609.88
# 9    Hubert         505.38
# 13  Woosung         449.62
# 16      Sam         440.84

# %%
old_pb = pd.read_csv(cwd + '\ExportData\PickBan\HLCS_pickban_11_7_2023.csv')
new_pb = pd.read_csv(cwd + '\ExportData\PickBan\HLCS_pickban_11_13_2023.csv')

set(old_pb[old_pb['Picks'] > 0]['Champion']).symmetric_difference(set(new_pb[new_pb['Picks'] > 0]['Champion']))
# Out:
# {'Aatrox', 'Kalista', 'Kayn', "Kha'zix", 'Nocturne', 'Zed'}

# %%
print(165 - len(new_pb[new_pb['Picks'] > 0]), "champions left.")
# Out:
# 71 champions left.

# %%
new_pb[new_pb['Picks'] > 2].sort_values('Winrate', ascending=False)
# Out:
#        Champion  Picks  Bans  Wins  Presence  Pickrate  Banrate  Winrate
# 24         Gnar    4.0   3.0   4.0     0.318     0.182    0.136    1.000
# 11   Blitzcrank    7.0  11.0   6.0     0.818     0.318    0.500    0.857
# 77        Swain    4.0   2.0   3.0     0.273     0.182    0.091    0.750
# 33         Jhin    7.0   3.0   5.0     0.455     0.318    0.136    0.714
# 4         Amumu    6.0   7.0   4.0     0.591     0.273    0.318    0.667
# 66       Rengar    3.0  13.0   2.0     0.727     0.136    0.591    0.667
# 46     Malphite    3.0  15.0   2.0     0.818     0.136    0.682    0.667
# 82      Trundle    3.0   7.0   2.0     0.455     0.136    0.318    0.667
# 31          Jax    3.0   4.0   2.0     0.318     0.136    0.182    0.667
# 34         Jinx    5.0   0.0   3.0     0.227     0.227    0.000    0.600
# 36       Kai'sa    7.0   5.0   4.0     0.545     0.318    0.227    0.571
# 30    Jarvan IV    4.0  12.0   2.0     0.727     0.182    0.545    0.500
# 3       Alistar    6.0   1.0   3.0     0.318     0.273    0.045    0.500
# 23        Garen    6.0   7.0   3.0     0.591     0.273    0.318    0.500
# 58      Orianna    4.0   2.0   2.0     0.273     0.182    0.091    0.500
# 54     Nautilus    7.0   1.0   3.0     0.364     0.318    0.045    0.429
# 90           Vi    5.0   5.0   2.0     0.455     0.227    0.227    0.400
# 70    Seraphine    5.0   0.0   2.0     0.227     0.227    0.000    0.400
# 26       Graves    3.0   5.0   1.0     0.364     0.136    0.227    0.333
# 50  Mordekaiser    3.0   7.0   1.0     0.455     0.136    0.318    0.333
# 51      Morgana    6.0   1.0   2.0     0.318     0.273    0.045    0.333
# 18       Ezreal    6.0   5.0   2.0     0.500     0.273    0.227    0.333
# 68      Sejuani    3.0   0.0   1.0     0.136     0.136    0.000    0.333
# 43        Leona    3.0   0.0   1.0     0.136     0.136    0.000    0.333
# 94        Xayah    4.0   3.0   1.0     0.318     0.182    0.136    0.250
# 78       Syndra    4.0   1.0   1.0     0.227     0.182    0.045    0.250
# 89          Vex    5.0   0.0   1.0     0.227     0.227    0.000    0.200
# 39       Kennen    3.0   1.0   0.0     0.182     0.136    0.045    0.000
# 1          Ahri    3.0   2.0   0.0     0.227     0.136    0.091    0.000
